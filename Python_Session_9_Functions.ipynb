# %% [markdown]
# **Functions**

# %% [markdown]
# - A block of code which we can use many times

# %%
num1=10
num2=20
add=(num1+num2)
print(add)
# Out:
# 30

# %% [markdown]
# **Functions without arguments**

# %%
import random

# %%
def:<function_name>():
    codelines

# %%
def addition():
        num1=10
        num2=20
        add=(num1+num2)
        print(add)

# %%
def additiona():
    num1=10
    num2=20
    adda=(num1+num2)
    print(adda)
additiona()
# Out:
# 30

# %%
# Function name : addition
# in order to excute code lines we need to call the function

# %%
addition()
# Out:
# 30

# %%
def addition():
        num1=10
        print("num1 is:",num1)
        num2=20
        print("num2 is:",num2)
        add=(num1+num2)
        print(f"the addition of {num1} and {num2} is {add}")
addition()
# Out:
# num1 is: 10
# num2 is: 20
# the addition of 10 and 20 is 30

# %% [markdown]
# ***Note***
# - function name can be anything
# - same rules applicable as variable rules
# - whenever you create the function make sure the indentation correctly
# - starting with keyword,ending with colon then code line start with indentation
# - brackets means functions
# - never miss the brackets whenever you call the funtion
# - if you want to excute the code we need to call the function
# - while you are calling the function if you see function or bound method which means you missed the brackets

# %% [markdown]
# def add one()  # wrong

# %% [markdown]
# - whenever we defined the function it does not throw until unless we call the function

# %%
# wap to creat the funtion for average 
# write noraml average code
def average ():
    a=30
    b=50
    c=20
    sum=a+b+c
    average=sum/3
    print(f"the average of a,b,c is {average}")
average()
# Out:
# the average of a,b,c is 33.333333333333336

# %% [markdown]
# **Note**
# - function name and variable name should not be same

# %%
def average ():
    a=random.randint(20,30)
    b=random.randint(30,40)
    c=random.randint(40,50)
    sum=(a+b+c)
    avg=round((a+b+c)/3,3)
    print(f"The addition of a,b,c is : {sum} and the average of the tree variables is {avg}")
average()
# Out:
# The addition of a,b,c is : 118 and the average of the tree variables is 39.333

# %%
def addition():
    Bill_amount=random.randint(4000,5000)
    Tip_percentage=random.randint(15,20)
    Tip_amount=Bill_amount*Tip_percentage/100
    Total_bill_amount=Bill_amount+Tip_amount
    dollar=eval(input("Enter the dollar value:"))
    Total_bill_in_dollars=round(dollar*Total_bill_amount,3)
    print(f"An actual bill amount is: {Bill_amount}, tip amount is :{Tip_amount} and an addition of actual bill,tip amount in INR is : {Total_bill_amount} the same bill amnount in dollars is : {Total_bill_in_dollars} ")
addition()
# Out:
# Enter the dollar value: 80
# An actual bill amount is: 4135, tip amount is :620.25 and an addition of actual bill,tip amount in INR is : 4755.25 the same bill amnount in dollars is : 380420.0

# %%
# Subtraction
def subtraction ():
    x=random.randint(19999,89999999)
    y=random.randint(2222222222,888888888888888)
    sub=x-y
    print(f"the subtraction  of x and y is : {sub}")
    
subtraction()
# Out:
# the subtraction  of x and y is : -72945660292443

# %%
# multiplication
def multiplication ():
    x=random.randint(19999,89999999)
    y=random.randint(2222222222,888888888888888)
    mul=x*y
    print(f"The multiplication of x and y is : {mul}")
multiplication()
# Out:
# The multiplication of x and y is : 3915364721609993802507

# %%
# Division
def division ():
    x=random.randint(19999,89999999)
    y=random.randint(2222222222,888888888888888)
    div=x/y
    print(f"The division of x and y is : {div}")
division()
# Out:
# The division of x and y is : 2.6050598035322134e-07

# %%
import math

# %%
# 7. wap ask the user enter radius values and pi value find the area of the circle
def rad ():
    
    radius=random.randint(25,30)
    pi=math.pi
    area=round(pi*radius*radius,2)
    print("An area of the circle is : {}".format(area))
rad()
# Out:
# An area of the circle is : 2827.43

# %%
def additon()
def area
def average

# %% [markdown]
# - while we are defining the function if nothing mentioned means its called without arguments

# %% [markdown]
# **Functions with arguments**
# - first look at how many argumentss or variables are there
# - in that how many input variables are there
# - how many output variables are ther
# - input variables means user get defined
# - output variable means python give the output
# - we can use only input variables as arguments inside the function

# %%
def addtion2(num1,num2):
    add=(num1+num2)
    print(f"the addtion of {num1} and {num2} is :{add}")
addtion2(10,20)
# Out:
# the addtion of 10 and 20 is :30

# %%
def average(num1,num2,num3):
    sum=(num1+num2+num3)
    avg=round(sum/3,2)
    print(f"the average of num1,num3,num3 is : {avg}")
average(50,25,33)
# Out:
# the average of num1,num3,num3 is : 36.0

# %%
def rad (radius,pi,area):
    print("An area of the circle is : {}".format(area))
rad(10,4,56)
# Out:
# An area of the circle is : 56

# %% [markdown]
# **NOTE**
# - function name and variable name should not be same

# %%
## Default arguments#
# bill amount problem
bil=eval(input("enter the bill amount"))
tip_percentage=eval(input("enter the tip percentage"))
tip_amount=(bil*tip_percentage)/100
total_bill=bil+tip_amount
print(f"the total bill is : {total_bill}")
# Out:
# enter the bill amount 2345
# enter the tip percentage 45
# the total bill is : 3400.25

# %%
# with arguments

def bill_pay (bil,tip_per):
    tip_amount=(bil*tip_percentage)/100
    total_bill=bil+tip_amount
    print(f"the total bill is : {total_bill}")
bill_pay(2345,45)
# Out:
# the total bill is : 3400.25

# %%
# with arguments

def bill_pay1 (bill,tip_per=20):
    print("bill is:",bill)
    print("tip_per is :",tip_per)
    tip_amount=(bill*tip_percentage)/100
    total_bill=bill+tip_amount
    print(f"the total bill is : {total_bill}")
bill_pay1(23405)
# Out:
# bill is: 23405
# tip_per is : 20
# the total bill is : 33937.25

# %%
# whenever we privided default value to a arguments
# then it is called default arguments

# %%
def average3 (num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    avg=(num1+num2+num3)/3
    avg1=round(avg,2)
    print(f"the average of the {num1},{num2} and {num3} is : {avg1}")
average3(30,40)
# Out:
# num1: 30
# num2: 40
# num3: 50
# the average of the 30,40 and 50 is : 40.0

# %%
def average3 (num1,num2=50,num3):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    avg=(num1+num2+num3)/3
    avg1=round(avg,2)
    print(f"the average of the {num1},{num2} and {num3} is : {avg1}")
average3(30,40)
# Out:
#   Cell In[17], line 1
#     def average3 (num1,num2=50,num3):
#                                ^
# SyntaxError: non-default argument follows default argument

# %%
def average3 (num1,num3,num2=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    avg=(num1+num2+num3)/3
    avg1=round(avg,2)
    print(f"the average of the {num1},{num2} and {num3} is : {avg1}")
average3(30,40)
# Out:
# num1: 30
# num2: 50
# num3: 40
# the average of the 30,50 and 40 is : 40.0

# %% [markdown]
# **NOTE**
# - default arguements always should be at last

# %%
average1(num1,anum2,num3=50) # works
average1(num1,anum2=50,num3) # f
average1(num1=50,anum2,num3)
average1(num1=50,anum2=56,num3)
average1(num1=50,anum2=45,num3=78)
average1(num1=50,anum2,num3)
# Out:
#   Cell In[20], line 2
#     average1(num1,anum2=50,num3) # f
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
# case 1
def addition (n1,n2=600):
    add=n1+n2
    print(add)
addition(500,1000)

# first wer are defining the function
# while defining the function we given n2=600
# while we are calling n2=1000 values will be overwrite
# python always takes the latest value
# Out:
# 1500

# %%
case 2
def addition2 (n1,n2=600):
    n2=1000
    add=n1+n2
    print(add)
addition2(500,1000)
# define the function n2=600
# call the function n2=1000
# running the funciton n2=1000
# Out:
# 1500

# %%
def addition2 (n1,n2=600):
    n2=2000
    add=n1+n2
    print(add)
n2=3000
addition2(500,1000)
# n2=600====3000====1000
# Out:
# 2500

# %% [markdown]
# ***Local variable and global variable***
# - local variable means : the variables inside the function call
# - Global variable means: the variable outside the function call
# - once you define the varianble s outside means , you can use thse variables anywhere
# - you can use global variables insede funtion also
# - but you can not use local varables outside the function

# %%
def multiplication1():
    a=10
    b=20
    mul=a*b
    print(mul)
multiplication1()
# a,b,mul are local variables
# these values we can not use outside the function
# Out:
# 200

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
a1=10
b1=20
def multiplication2():
    mul1=a1*b1
    print(mul1)
multiplication2()
# Out:
# 200

# %%
mul1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 mul1
#
# NameError: name 'mul1' is not defined

# %%
a1=100
b1=200
def add11(a1=1000):
    add4=a1+b1
    print(add4)
add11()
# a1=100===a1=1000===1000+200
# global variable intialization=a1=100
# define the function a1=1000
# call the function a1=1000
# running the function a1=1000
# Out:
# 1200

# %%
# case 6 :
a1=100
b1=200
def add11(a1=1000):
    add4=a1+b1
    print(add4)
add11(a1=2000,b1=3000)
# while defining function only one argument is there
# while calling we are providing two arguments
# it is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 7
#       5     add4=a1+b1
#       6     print(add4)
# ----> 7 add11(a1=2000,b1=3000)
#
# TypeError: add11() got an unexpected keyword argument 'b1'

# %%
# case 7 :
a1=100
b1=200
def add11(a1=1000):
    add4=a1+b1
    print(add4)
add11(a1=2000)
# Out:
# 2200

# %%
# case 8 :
a1=100
b1=200
def add11(a1=1000):
    a1=5000
    add4=a1+b1
    print(add4)
add11(a1=2000)
# Out:
# 5200

# %%
a1
# Out:
# 100

# %%
# case 9 :
a1=100
b1=200
def add11(a1=1000):
    add4=a1+b1
    print(add4)
a1=6000
add11(a1=2000)
# Out:
# 2200

# %%
a1
# Out:
# 6000

# %%
# case 10 :
b1=200
def add11():
    add4=a1+b1
    print(add4)
a1=6000
add11()
# b1=200
# difine the function
# calling the function
# running the function
# Out:
# 6200

# %%
s=0
def add():
    s=s+10
    print(s)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3     s=s+10
#       4     print(s)
# ----> 5 add()
#
# Cell In[1], line 3, in add()
#       2 def add():
# ----> 3     s=s+10
#       4     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
s=0
def add():
    a=s+10
    print(a)
add()
# Out:
# 10

# %%
s=0 
def add():
    c=s+10
    s=c
    print(s)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 6
#       4     s=c
#       5     print(s)
# ----> 6 add()
#
# Cell In[4], line 3, in add()
#       2 def add():
# ----> 3     c=s+10
#       4     s=c
#       5     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
n1=10
def addition():
    n1=100
    n2=200
    n3=n1+n2
    print(n1,n2,n3)
addition()
# note
# if you give same variable as global and local then make sure that the veiable should not use as value inside the funciton
# Out:
# 100 200 300

# %%
n1=10
def addition9():
    n2=200+n1
    n3=n1+n2
    print(n1,n2,n3)
addition9()
# step 1: n1=10
# step2 2: define the function
# step 3: call the function
# step 4 :run the function
#
# Out:
# 10 210 220

# %%
s=0 
def add():
    c=s+10
    s=c
    print(s)
add()

# c is lv 
# we are creating the new variable like global varaible
# we are creation the new varible with same name as global variable by using the global variable
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 6
#       4     s=c
#       5     print(s)
# ----> 6 add()
#
# Cell In[9], line 3, in add()
#       2 def add():
# ----> 3     c=s+10
#       4     s=c
#       5     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
a=100
def greet():
    value=200
    print("Hello")
greet()
# Out:
# Hello

# %%
**Global variable**
- global key word is used to take the locla variable value outside the function
-
# Out:
#   Cell In[11], line 1
#     **Global variable**
#     ^
# SyntaxError: invalid syntax

# %%
a=100
def greet():
    global value
    value=200
    print("Hello")
greet()
print('value:',value)
# Out:
# Hello
# value: 200

# %%
n1=10
def addition9():
    global n3 ,n2
    n2=200+n1
    n3=n1+n2
    print(n1,n2,n3)
addition9()
print(n3,n2)
# Out:
# 10 210 220
# 220 210

# %%
n2
# Out:
# 210

# %% [markdown]
# - outside the function called global variable
# -  inside the funtion is local varable
# - local vriables can not use outside the function
# - if you wnt to usse outside the function use blobal keyword

# %%
def mult(a,b):
    print(a*b)
mult(eval(input()),eval(input()))
# Out:
#  45
#  67
# 3015

# %% [markdown]
# **Return**
# - we can use the local vareible or funtion outputs outside the function
# - print is different
# - return is differnet
# - print is used to only to print the values
# - that value yuou only see but you can not use
# - if you want to use outside we will use retrun (it also possible by using the global)

# %%
def average7():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    print(avg)
average7()
# Out:
# 20.0

# %%
def average7():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg)
avg=average7()

# funtion is ready to retrun the values to me
# so i need to store

# %%
avg
# Out:
# 20.0

# %%
def average7():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg,n3)
avg=average7()

# how many values we are returning 
# we will store each return values in differnt variable
# because two values are differenct 
# if you use only variable to store : tuple value

# %%
avg
# Out:
# (20.0, 30)

# %%
# return always at last line of the function
# not in middle lines

# %%
def sub():
    n1=10
    n2=20
    subb=n2-n1
    return(subb,n1,n2)
subb =sub()

# %%
subb
# Out:
# (10, 10, 20)

# %%
def sub():
    n1=10
    n2=20
    sub1=n2-n1
    return(sub1,n1)
bala=sub()

# %%
bala
# Out:
# (10, 10)

# %% [markdown]
# *unbound local error*

# %%
num=10
def fun():
    num=100
    print(num)
fun()
# Out:
# 100

# %%
num1=10  # gv
def fun1():
    print(num1)
    num1=100 # lv
fun1()
## name error will come
# loval varial and global variable both name are same
# you are trying to access local vareiable before assigning
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[49], line 5
#       3     print(num1)
#       4     num1=100 # lv
# ----> 5 fun1()
#
# Cell In[49], line 3, in fun1()
#       2 def fun1():
# ----> 3     print(num1)
#       4     num1=100
#
# UnboundLocalError: cannot access local variable 'num1' where it is not associated with a value

# %%
a1=100
b1=200
def brs():
    print(adding)
    adding=a1+b1
brs()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[52], line 6
#       4     print(adding)
#       5     adding=a1+b1
# ----> 6 brs()
#
# Cell In[52], line 4, in brs()
#       3 def brs():
# ----> 4     print(adding)
#       5     adding=a1+b1
#
# UnboundLocalError: cannot access local variable 'adding' where it is not associated with a value

# %%
a1=100
b1=200
def brs():
    adding=a1+b1
    print(adding)
    
brs()
# Out:
# 300

# %%
num2=10
def fun3():
    num2=100
    print(num2)
fun3()
# Out:
# 100

# %%
a1=100
b1=200
def add01():
    add1=a1+b1
    print(add1)
add01()
# Out:
# 300

# %%
a1=100
b1=200
def add02():
    add2=a1+b1
    a1=700
    b1=80
    print(add2)
add02()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[57], line 8
#       6     b1=80
#       7     print(add2)
# ----> 8 add02()
#
# Cell In[57], line 4, in add02()
#       3 def add02():
# ----> 4     add2=a1+b1
#       5     a1=700
#       6     b1=80
#
# UnboundLocalError: cannot access local variable 'a1' where it is not associated with a value

# %%
a1=100
b1=200
def add03():
    a1=700
    b1=80
    add3=a1+b1
    print(add3)
add03()
# Out:
# 780

# %%
# case 1: here no local veriables as same name as global vareable ============> no error
# case2:wer are initialization lv name same as gv we are using after initialization=============> no error
#case3:wer are initialization lv name same as gv we are using before initialization==============>>>Error

# %%
b21=200
def add34():
    add32=a21+b21
    b21=5000
    a21=6000
    print(add32)
add34()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[62], line 7
#       5     a21=6000
#       6     print(add32)
# ----> 7 add34()
#
# Cell In[62], line 3, in add34()
#       2 def add34():
# ----> 3     add32=a21+b21
#       4     b21=5000
#       5     a21=6000
#
# UnboundLocalError: cannot access local variable 'a21' where it is not associated with a value

# %%
b21=200
def add34():
    b21=5000
    a21=6000
    add32=a21+b21
    print(add32)
add34()
# Out:
# 11000

# %% [markdown]
# ***Functions in function***

# %%
def greet1():
    print("hello good morning")
def greet2():
    print("good night")
greet1()
greet2()
# Out:
# hello good morning
# good night

# %%
def greet1():
    print("hello good morning")
    greet2()
def greet2():
    print("good night")
greet1()
# Out:
# hello good morning
# good night

# %%
def greet2():
    print("good night")
    greet1()
def greet1():
    print("hello good morning")
    
greet1()
# Out:
# hello good morning

# %%
def greet2():
    print("good night")
    greet1()
def greet1():
    print("hello good morning")
    greet2()
greet1()
# Out:
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# ...

# %% [markdown]
# - functions without arguments
# - function with arguments
# - functions default arguments
# - global variable vs local variable
# - global keyword
# - return statements
# -

# %%
#.3
# wap ask the user enter the distance
# cutoff distance enter 25
# if distance greater than 25km
#      print("good news your charge is aplicable for only remaining of 25")
#      chargeble distance= distance-cutoff
#      then enter the charge
#      print the total cost
#otherwise
#      print free ride
distance=eval(input("enter the distance in km"))
cutoff=eval(input("Enter the cutoff distance :"))
total_cost=chargeble_distance*charge
if distance>cutoff:
    charge=eval(input("Enter the charge for 1km:"))
    chargeble_distance=distance-cutoff
    print("good news your charge is aplicable for only remaining of ",chargeble_distance)
    print(f"the total cost for the raid is :{total_cost}")
else:
    print("enjoy the free raid")

# %%
#.3
# wap ask the user enter the distance
# cutoff distance enter 25
# if distance greater than 25km
#      print("good news your charge is aplicable for only remaining of 25")
#      chargeble distance= distance-cutoff
#      then enter the charge
#      print the total cost
#otherwise
#      print free ride
def dis():
    
    distance=eval(input("enter the distance in km"))
    cutoff=eval(input("Enter the cutoff distance :"))
    chargeble_distance=distance-cutoff
    charge=eval(input("Enter the charge for 1km:"))
    total_cost=chargeble_distance*charge
    
    if distance>cutoff:
        
        print("good news your charge is aplicable for only remaining of ",chargeble_distance)
        print(f"the total cost for the raid is :{total_cost}")
    else:
        print("enjoy the free raid")
dis()
# Out:
# enter the distance in km 50
# Enter the cutoff distance : 25
# Enter the charge for 1km: 5
# good news your charge is aplicable for only remaining of  25
# the total cost for the raid is :125

# %%
#.3
# wap ask the user enter the distance
# cutoff distance enter 25
# if distance greater than 25km
#      print("good news your charge is aplicable for only remaining of 25")
#      chargeble distance= distance-cutoff
#      then enter the charge
#      print the total cost
#otherwise
#      print free ride
def dis(distance,cutoff,charge):
    if distance>cutoff:
        chargeble_distance=distance-cutoff
        total_cost=chargeble_distance*charge
        print("good news your charge is aplicable for only remaining of ",chargeble_distance)        
        print(f"the total cost for the raid is :{total_cost}")
    else:
        print("enjoy the free raid")
dis(60,25,5)
# Out:
# good news your charge is aplicable for only remaining of  35
# the total cost for the raid is :175

# %%
def dis2(distance,cutoff,charge):
    if distance>cutoff:
        chargeble_distance=distance-cutoff
        total_cost=chargeble_distance*charge
        print("good news your charge is aplicable for only remaining of ",chargeble_distance)
        print(f"the total cost for the raid is :{total_cost}")
    else:
        print("enjoy the free raid")
        
total_cost=dis2(100,25,10)
# Out:
# good news your charge is aplicable for only remaining of  75
# the total cost for the raid is :750

# %%
distance=eval(input("enter the distance in km"))
cutoff=eval(input("Enter the cutoff distance :"))
def dis3():
    if distance>cutoff:
        global charge=5
        chargeble_distance=distance-cutoff
        total_cost=chargeble_distance*charge
        print(f"the total cost for the raid is :{total_cost}")
        print("good news your charge is aplicable for only remaining of ",chargeble_distance)
        
    else:
        print("enjoy the free raid")
        
dis3()
print(charge)
# Out:
#   Cell In[19], line 5
#     global charge=5
#                  ^
# SyntaxError: invalid syntax

# %%
# first create 4 fuction individual fuction
# func1 add
# fuc2 sub
# func3 mul
# fuc4 div
def add (a,b):
    print(a+b)

# crate a main function name : calculator
# inside main function
# print some statements
# option : addition
# option 2 sub,opt3 mul,opt4 div
# option = eval(input(1-4)
# a value
# b value
# if option==1
#   add function
# elif option==2
#    sub function
# elif option==3
#   mult
# elif option=4
#   div function

# %%
def add9 (a,b):
    c=a+b
    print(c)
add9(10,20)
# Out:
# 30

# %%
def sub9 (a,b):
    c=a-b
    print(c)
sub9(30,40)
# Out:
# -10

# %%
def mul9(a=20,b=50):
    c=a*b
    print(c)
mul9()
# Out:
# 1000

# %%
def div9 (a,b):
    c=a/b
    print(c)
div9(eval(input("enter the a value:")),eval(input("enter the b value:")))
# Out:
# enter the a value: 2
# enter the b value: 1
# 2.0

# %%
## crate a main function name : calculator
# inside main function
# print some statements
# option : addition
# option 2 sub,opt3 mul,opt4 div
# option = eval(input(1-4)
# a value
# b value
# if option==1
#   add function
# elif option==2
#    sub function
# elif option==3
#   mult
# elif option=4
#   div function
def calculator(a,b):
    print("option 1 = addition function ")
    print("optiont 2 = subtraction function")
    print("option 3 = multiplication function")
    print("option 4 = division function")
    option=eval(input("enter the value of option"))
    if option==1:
        add9(a,b)
    elif option==2:
        sub9(a,b)
    elif option==3:
        mul9(a,b)
    elif option==4:
        div(a,b)
    else:
        print("enter the valid number")   
    
calculator(20,40)
# Out:
# option 1 = addition function
# optiont 2 = subtraction function
# option 3 = multiplication function
# option 4 = division function
# enter the value of option 3
# 800
